# %%
import pandas as pd

# %%
df = pd.read_csv('asian_out_raw.csv')

# %%
sample = pd.read_csv('asian_selected.csv')

# %%
merge = sample.merge(df,how='inner', left_on='path', right_on='jobName')

# %%
merge.drop(axis=1,labels=['Unnamed: 0','client_id','path']).to_csv('aws_asian_results.csv',index=False)
